# %%
def selectWord():
	file = open('FREQ')
	words = file.readlines() 
	myword = 'a'
	while len(myword) < 4: # makes sure word is at least 4 letters long
	  myword = random.choice(words)
  	myword = str(myword).strip('[]')
  	myword = str(myword).strip("''")
  	myword = str(myword).strip("\n")
  	myword = str(myword).strip("\r")
	myword = myword.lower()
	return myword

# %%
#Word list
#guess letter
#secret word
#blanks
while secret_word is not found:
    for guess letter in range(len(secret_word)):
        if guess_letter in secret_word


print





import random
HANGMAN = ['''
 +---+
     |
     |
     |
    ===''', '''
 +---+
 0   |
     |
     |
    ===''', '''
 +---+
 0   |
 |   |
     |
    ===''', '''
 +---+
 0   |
/|   |
     |
    ===''', '''
 +---+
 0   |
/|\  |
     |
    ===''', '''
 +---+
 0   |
/|\  |
/    |
    ===''', '''
 +---+
 O   |
/|\  |
/ \  |
    ===''']
#Welcoming the player
name = input("Enter your name: ")
print('All the best!',name)
# Word list
import random
wordlist = 'panda cat peacock parrot jaguar deer'.split()
#word = random.choice(Words)
#Secret word - Random pick of words
def getRandomWord(wordlist):
    wordIndex = random.randint(0,len(wordlist)-1)
    return wordlist(wordIndex)
#Game board - display wrong guessed/missed word
def gameboard(missed_letters,correct_letters,secret_word):
    print(HANGMAN(missed_letters()))
    print()
    print('Missed Letters:', end= '')
    for letters in missed_letters :
        print(letters,end=' ') 
    print()
# Replacing the blanks with correct words
    guess_blanks = '_'*len(secret_word)
    for i in range(len(secret_word)):
        if secret_word[i] in secret_word:
            guess_blanks = guess_blanks[:i] + secret_word[i] + guess_blanks[i+1:]
#Displaying the correct guessed word
    for letters in guess_blanks:
        print(letters, end='')
    print()x

    while True:
        guess = input()
        print('Guess aletter')
        if guess.is


        for i in range(len(secret_word)):
        if secret_word[i] in secret_word:
            guess_blanks = guess_blanks[:i] + secret_word[i] + guess_blanks[i+1:]
