# %%
#Word list
#guess letter
#secret word
#blanks


import random
HANGMAN = ['''
 
    ===''','''
 
     |
     |
     |
    ===''','''
 +---+
     |
     |
     |
    ===''', '''
 +---+
 0   |
     |
     |
    ===''', '''
 +---+
 0   |
 |   |
     |
    ===''', '''
 +---+
 0   |
/|   |
     |
    ===''', '''
 +---+
 0   |
/|\  |
     |
    ===''', '''
 +---+
 0   |
/|\  |
/    |
    ===''', '''
 +---+
 O   |
/|\  |
/ \  |
    ===''']
class Hangman:
    def__init__(self,words,secretwords,blanks):
    3

    words = "blue red black white".split(',')
